# %%
import json
import pandas as pd
from pathlib import Path

data_dir = Path("/Users/kushpreetsingh/WMK/project101/ipl-fantasy/data/raw/IPL Match Data")

match_files = list(data_dir.glob("*.json"))
print(f"Found {len(match_files)} match files")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import json
# ----> 2 import pandas as pd
#       3 from pathlib import Path
#       4
#       5 data_dir = Path("/Users/kushpreetsingh/WMK/project101/ipl-fantasy/data/raw/IPL Match Data")
#
# ModuleNotFoundError: No module named 'pandas'
